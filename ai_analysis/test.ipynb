# %%
from PIL import ImageTk, Image
import tkinter

# %%
image = Image.open("yolo-comparison-plots.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=3840x1440>

# %%
root = tkinter.Tk()
# imag = Image.open("yolo-comparison-plots.png")
# imag = Image.open("test6.png")
imag = Image.open("test0.jpg")
img = ImageTk.PhotoImage(imag)
tk = tkinter.Label(root,image=img)
tk.image = img
tk.pack()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[26], line 7
#       5 img = ImageTk.PhotoImage(imag)
#       6 tk.image = img
# ----> 7 tk = tkinter.Label(root,image=img)
#       8 tk.pack()
#       9 root.mainloop()
#
# File c:\Users\Tommy AU\.conda\envs\myenv\lib\tkinter\__init__.py:3187, in Label.__init__(self, master, cnf, **kw)
#    3169 def __init__(self, master=None, cnf={}, **kw):
#    3170     """Construct a label widget with the parent MASTER.
#    3171
#    3172     STANDARD OPTIONS
#    (...)
#    3185
#    3186     """
# -> 3187     Widget.__init__(self, master, 'label', cnf, kw)
#
# File c:\Users\Tommy AU\.conda\envs\myenv\lib\tkinter\__init__.py:2601, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2599 for k, v in classes:
#    2600     del cnf[k]
# -> 2601 self.tk.call(
# ...

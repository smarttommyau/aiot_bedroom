# %%
from ultralytics import YOLO
from PIL import Image
from io import BytesIO, StringIO
import cv2
import torch

# %%
model = YOLO("yolov8m.pt") # default yolov5x6
# Out:
# ...
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]

# %%
result = model.predict("runs/detect/exp/test2.jpg",classes=[0,59,63,67])
# Out:
# image 1/1 d:\my programs\python\Aiot\aiot_bedroom\ai_analysis\runs\detect\exp\test2.jpg: 640x480 2 laptops, 440.3ms
# Speed: 3.0ms preprocess, 440.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
result[0].boxes.xyxy[0]
# Out:
# tensor([116.3314, 142.8589, 479.2811, 563.1343])

# %%
img = Image.fromarray(result[0].plot(pil=True))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x640>
